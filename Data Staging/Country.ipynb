# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import warnings

from datetime import datetime, timedelta
from IPython.display import display

warnings.filterwarnings("ignore")

# %% [markdown]
# Read Data with Pandas

# %%
country_data_raw = pd.read_csv("Country_Data_Raw.csv")#read input data

country_transposed = country_data_raw.transpose()#flip dataframe

final_table = country_transposed.iloc[:1,[0,9,18,27,36,45,54,63,72,81,90,99,108]]#create data frame header columns
final_table.columns = range(final_table.columns.size)

count_start = 0
count_end = 12
for i in range(9):
     transposed_country = country_transposed.iloc[4:,[0+count_start,9+count_start,18+count_start,27+count_start,36+count_start,45+count_start,54+count_start,63+count_start,72+count_start,81+count_start,90+count_start,99+count_start,108+count_start]]
     transposed_country.columns = range(transposed_country.columns.size)

     #Male and female birth rates appear to have an up and down variance (BUT LIMITED IN EITHER DIRECTION) as time progresses without a clear relationship. In this case we beleive it is safe to
     #average out the values for each country and use that to fill the gaps. The data has no outliers and is fairly tightly packed
     transposed_country[7] = pd.to_numeric(transposed_country[7], errors='coerce')
     transposed_country[7].replace({np.NaN: transposed_country[7].mean()}, inplace=True)

     transposed_country[8] = pd.to_numeric(transposed_country[8], errors='coerce')
     transposed_country[8].replace({np.NaN: transposed_country[8].mean()}, inplace=True)

     #lO
     transposed_country[11] = pd.to_numeric(transposed_country[11], errors='coerce')
     transposed_country[11].replace({np.NaN: transposed_country[11].mean()}, inplace=True)
     
     final_table = pd.concat([final_table, transposed_country], axis=0, ignore_index=True)

     count_start = count_start + 1

#Fill all empty values with NaN
final_table.replace({'..': np.nan}, inplace = True)
#Birth and death rate have limited variance, it is safe to use the previous fill given it is from only a year ago
final_table[0].fillna(method="ffill", inplace=True)
final_table[2].fillna(method="ffill", inplace=True)
final_table.head(50)
# Out:
#                                       0                  1   \
# 0   Birth rate, crude (per 1,000 people)  Population, total
# 1                                   10.6           32243753
# 2                                   10.9           32571174
# 3                                   11.2           32889025
# 4                                   11.3           33247118
# 5                                   11.3           33628895
# 6                                   11.1           34004889
# 7                                     11           34339328
# 8                                     11           34714222
# 9                                   10.8           35082954
# 10                                  10.8           35437435
# 11                                  10.7           35702908
# 12                                  10.6           36109487
# 13                                  10.3           36545295
# 14                                  10.1           37065178
# 15                                   9.9           37593384
# 16                                   9.9           38005238
# 17                                    14          295516599
# 18                                  14.3          298379912
# 19                                  14.3          301231207
# 20                                    14          304093966
# 21                                  13.5          306771529
# 22                                    13          309327143
# 23                                  12.7          311583481
# 24                                  12.6          313877662
# 25                                  12.4          316059947
# 26                                  12.5          318386329
# 27                                  12.4          320738994
# 28                                  12.2          323071755
# 29                                  11.8          325122128
# 30                                  11.6          326838199
# 31                                  11.4          328329953
# 32                                  11.4          329484123
# 33                                42.981            7364857
# 34                                43.053            7607850
# 35                                43.102            7862226
# 36                                 43.11            8126104
# 37                                43.057            8397661
# 38                                42.919            8675606
# 39                                42.682            8958406
# 40                                 42.35            9245992
# 41                                41.933            9540302
# 42                                 41.44            9844301
# 43                                40.883           10160034
# 44                                40.278           10488002
# 45                                39.646           10827010
# 46                                39.008           11175379
# 47                                38.377           11530577
# 48                                38.377           11890781
# 49                                49.325           10096630
#
#                                       2   \
# 0   Death rate, crude (per 1,000 people)
# 1                                    7.1
# 2                                      7
# 3                                    7.1
# 4                                    7.2
# 5                                    7.1
# 6                                      7
# 7                                    7.1
# 8                                    7.1
# 9                                    7.2
# 10                                   7.3
# 11                                   7.4
# 12                                   7.4
# 13                                   7.5
# 14                                   7.7
# 15                                   7.6
# 16                                   7.6
# 17                                   8.3
# 18                                   8.1
# 19                                     8
# 20                                   8.1
# 21                                   7.9
# 22                                 7.995
# 23                                 8.073
# 24                                 8.102
# 25                                 8.215
# 26                                 8.237
# 27                                  8.44
# 28                                 8.493
# 29                                 8.638
# 30                                 8.678
# 31                                   8.7
# 32                                   8.7
# 33                                12.239
# 34                                11.791
# 35                                 11.36
# 36                                10.936
# 37                                10.519
# 38                                10.113
# 39                                 9.728
# 40                                 9.373
# 41                                 9.052
# 42                                 8.767
# 43                                 8.517
# 44                                   8.3
# 45                                 8.106
# 46                                 7.929
# 47                                 7.766
# 48                                 7.766
# 49                                16.636
#
#                                             3   \
# 0   GNI per capita, Atlas method (current US$)
# 1                                        34810
# 2                                        38510
# 3                                        43090
# 4                                        45650
# 5                                        43230
# 6                                        44490
# 7                                        47190
# 8                                        51080
# 9                                        52800
# 10                                       52200
# 11                                       47590
# 12                                       43890
# 13                                       42900
# 14                                       45080
# 15                                       46550
# 16                                       43580
# 17                                       46180
# 18                                       47850
# 19                                       48520
# 20                                       49090
# 21                                       47830
# 22                                       49140
# 23                                       50630
# 24                                       52780
# 25                                       53980
# 26                                       55800
# 27                                       56640
# 28                                       57130
# 29                                       59240
# 30                                       63490
# 31                                       65970
# 32                                       64530
# 33                                         140
# 34                                         150
# 35                                         170
# 36                                         190
# 37                                         200
# 38                                         220
# 39                                         230
# 40                                         250
# 41                                         260
# 42                                         260
# 43                                         260
# 44                                         260
# 45                                         260
# 46                                         250
# 47                                         240
# 48                                         230
# 49                                         470
#
#                                               4                   5   \
# 0   Labor force, female (% of total labor force)  Labor force, total
# 1                                    46.63737609            17821886
# 2                                     46.8751721            18030705
# 3                                     47.0367127            18379605
# 4                                    46.97475419            18667574
# 5                                    47.20037683            18799155
# 6                                    47.31051354            19001081
# 7                                    47.26751603            19147395
# 8                                    47.39299543            19322866
# 9                                    47.46647388            19546552
# 10                                   47.32607559            19629145
# 11                                   47.17306195            19747709
# 12                                   47.30072881            19955331
# 13                                   47.40507966            20218270
# 14                                   47.50117139            20396697
# 15                                   47.38180361            20788261
# 16                                   47.09236951            20492683
# 17                                   45.88541943           151976098
# 18                                   45.86670406           153855509
# 19                                   45.90911393           155224880
# 20                                   46.05633577           156907793
# 21                                   46.27445911           157079943
# 22                                   46.27768454           157111093
# 23                                   46.26629636           157163170
# 24                                    46.1698979           157841889
# 25                                   46.08764735           158252925
# 26                                   46.14571941           158910317
# 27                                   46.05790055           159912569
# 28                                   46.04152378           161836238
# 29                                   46.17612365           163395307
# 30                                   46.19075536           164634753
# 31                                   46.29959035           166355636
# 32                                   46.29551159           163738061
# 33                                   51.93673772             3233143
# 34                                   51.89216761             3352425
# 35                                   51.84928405             3476102
# 36                                   51.80978675             3601032
# 37                                   51.77533385             3723694
# 38                                    51.7486529             3842129
# 39                                    51.7475804             3943624
# 40                                   51.75149668             4042457
# 41                                   51.75706009             4140069
# 42                                   51.76139565             4239621
# 43                                   51.72802017             4370030
# 44                                   51.69815523             4508039
# 45                                   51.67517542             4654229
# 46                                   51.66120937             4808244
# 47                                   51.65892761             4969385
# 48                                   51.63141352             5089758
# 49                                   43.20706277             3421436
#
#                                                    6   \
# 0   Age dependency ratio (% of working-age populat...
# 1                                           44.495093
# 2                                         44.23699432
# 3                                         44.03477573
# 4                                         43.93390259
# 5                                         43.97675318
# 6                                         44.17994479
# 7                                         44.64763374
# 8                                         45.13918539
# 9                                         45.70697547
# 10                                        46.38054112
# 11                                        47.15645579
# 12                                        47.82631443
# 13                                        48.61607607
# 14                                        49.48187729
# 15                                        50.36191603
# 16                                        51.23928687
# 17                                        49.68456775
# 18                                        49.69711035
# 19                                         49.6149867
# 20                                        49.52142753
# 21                                        49.52581393
# 22                                        49.67051522
# 23                                        49.86975262
# 24                                        50.11544312
# 25                                        50.42591564
# 26                                        50.79303992
# 27                                        51.20955055
# 28                                        51.64616731
# 29                                        52.15580602
# 30                                        52.71067711
# 31                                        53.27766617
# 32                                        53.85248134
# 33                                        97.06056981
# 34                                        95.22760708
# 35                                         93.4754245
# 36                                        91.91651195
# 37                                        90.66561287
# 38                                         89.7575691
# 39                                        89.79058518
# 40                                        89.95376678
# 41                                        90.23472707
# 42                                        90.57073454
# 43                                        90.89992856
# 44                                        91.19375026
# 45                                        91.35920407
# 46                                        91.38249684
# 47                                        91.25120127
# 48                                        90.95652981
# 49                                        107.6489463
#
#                              7                              8   \
# 0   Age at first marriage, male  Age at first marriage, female
# 1                          28.7                          26.98
# 2                          28.6                           26.6
# 3                          28.7                          26.98
# 4                          28.7                          26.98
# 5                          28.7                          26.98
# 6                          28.7                          26.98
# 7                          28.6                           26.9
# 8                          28.7                          26.98
# 9                          28.8                           27.1
# 10                         28.7                          26.98
# 11                         28.8                           27.1
# 12                         28.7                           27.2
# 13                         28.7                          26.98
# 14                         28.7                          26.98
# 15                         28.7                          26.98
# 16                         28.7                          26.98
# 17                         29.2                           25.6
# 18                         29.2                           25.6
# 19                         29.2                           23.7
# 20                         29.2                           25.6
# 21                         29.2                           25.6
# 22                         29.2                           27.5
# 23                         29.2                           25.6
# 24                         29.2                           25.6
# 25                         29.2                           25.6
# 26                         29.2                           25.6
# 27                         29.2                           25.6
# 28                         29.2                           25.6
# 29                         29.2                           25.6
# 30                         29.2                           25.6
# 31                         29.2                           25.6
# 32                         29.2                           25.6
# 33                         25.5                           21.6
# 34                         25.4                          22.15
# 35                         25.4                          22.15
# 36                         24.6                           22.1
# 37                         25.4                          22.15
# 38                         25.4                           22.1
# 39                         25.4                          22.15
# 40                         25.4                          22.15
# 41                         25.4                          22.15
# 42                         25.4                          22.15
# 43                         25.4                          22.15
# 44                         26.1                           22.8
# 45                         25.4                          22.15
# 46                         25.4                          22.15
# 47                         25.4                          22.15
# 48                         25.4                          22.15
# 49                         24.8                          18.55
#
#                            9                            10  \
# 0   Age dependency ratio, old  Age dependency ratio, young
# 1                 18.95421925                  25.54087375
# 2                 19.13834588                  25.09864844
# 3                 19.35344295                  24.68133278
# 4                 19.62097814                  24.31292445
# 5                 19.96659698                   24.0101562
# 6                 20.40672487                  23.77321992
# 7                 20.90334426                  23.74428949
# 8                 21.48625689                  23.65292849
# 9                 22.15015152                  23.55682395
# 10                22.86956698                  23.51097413
# 11                23.62395809                   23.5324977
# 12                24.32483539                  23.50147904
# 13                25.03064915                  23.58542692
# 14                25.75872729                     23.72315
# 15                26.53571732                  23.82619871
# 16                27.38090851                  23.85837836
# 17                18.42873209                  31.25583566
# 18                18.53387335                    31.163237
# 19                18.65978389                  30.95520281
# 20                18.83239533                  30.68903221
# 21                19.08345408                  30.44235985
# 22                19.42988579                  30.24062943
# 23                19.85813508                  30.01161754
# 24                20.35780389                  29.75763923
# 25                20.91679038                  29.50912526
# 26                21.51469796                  29.27834196
# 27                22.14144011                  29.06811045
# 28                22.79799773                  28.84816957
# 29                23.46146061                  28.69434541
# 30                24.13997563                  28.57070148
# 31                24.84570588                  28.43196029
# 32                  25.587092                  28.26538933
# 33                4.485549547                  92.57502026
# 34                4.407617004                  90.81999008
# 35                4.330653826                  89.14477068
# 36                4.254441289                  87.66207066
# 37                4.177216742                  86.48839613
# 38                4.100401974                  85.65716713
# 39                4.057304922                  85.73328026
# 40                4.010152243                  85.94361454
# 41                3.974224609                  86.26050246
# 42                3.968372885                  86.60236166
# 43                4.000974789                  86.89895377
# 44                4.082554558                   87.1111957
# 45                4.184571411                  87.17463265
# 46                4.300248832                  87.08224801
# 47                4.421911215                  86.82929006
# 48                4.545028976                  86.41150083
# 49                5.598870177                  102.0500761
#
#                                         11  \
# 0   Completeness of birth registration (%)
# 1                                    100.0
# 2                                    100.0
# 3                                    100.0
# 4                                    100.0
# 5                                    100.0
# 6                                    100.0
# 7                                    100.0
# 8                                    100.0
# 9                                    100.0
# 10                                   100.0
# 11                                   100.0
# 12                                   100.0
# 13                                   100.0
# 14                                   100.0
# 15                                   100.0
# 16                                   100.0
# 17                                   100.0
# 18                                   100.0
# 19                                   100.0
# 20                                   100.0
# 21                                   100.0
# 22                                   100.0
# 23                                   100.0
# 24                                   100.0
# 25                                   100.0
# 26                                   100.0
# 27                                   100.0
# 28                                   100.0
# 29                                   100.0
# 30                                   100.0
# 31                                   100.0
# 32                                   100.0
# 33                                    60.0
# 34                                    72.9
# 35                                    72.9
# 36                                    72.9
# 37                                    72.9
# 38                                    75.2
# 39                                    72.9
# 40                                    72.9
# 41                                    72.9
# 42                                    72.9
# 43                                    72.9
# 44                                    72.9
# 45                                    83.5
# 46                                    72.9
# 47                                    72.9
# 48                                    72.9
# 49                                   13.85
#
#                                                    12
# 0   Completeness of death registration with cause-...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 100
# 5                                                 NaN
# 6                                                 100
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                100
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                 98
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                100
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %% [markdown]
# Add Column Labels to Dataframe

# %%
final_table.columns=["Birth_Rate_Crude_Per_1000", "Population_Total_Count","Death_Rate_Crude_Per_1000", "GNI_Per_Capita_USD", "Labour_Force_Female_Percent", "Labour_Force_Total_Count", "Age_Dependency_Ratio_Percent_Working_Age", "Age_First_Marriage_Male", "Age_First_Marriage_Female", "Age_Dependency_Ratio_Old", "Age_Dependency_Ratio_Young", "Completeness_Birth_Registration_Percent", "Completeness_Death_Registration_Percent"]
final_table.head(2)
# Out:
#               Birth_Rate_Crude_Per_1000 Population_Total_Count  \
# 0  Birth rate, crude (per 1,000 people)      Population, total
# 1                                  10.6               32243753
#
#               Death_Rate_Crude_Per_1000  \
# 0  Death rate, crude (per 1,000 people)
# 1                                   7.1
#
#                            GNI_Per_Capita_USD  \
# 0  GNI per capita, Atlas method (current US$)
# 1                                       34810
#
#                     Labour_Force_Female_Percent Labour_Force_Total_Count  \
# 0  Labor force, female (% of total labor force)       Labor force, total
# 1                                   46.63737609                 17821886
#
#             Age_Dependency_Ratio_Percent_Working_Age  \
# 0  Age dependency ratio (% of working-age populat...
# 1                                          44.495093
#
#        Age_First_Marriage_Male      Age_First_Marriage_Female  \
# 0  Age at first marriage, male  Age at first marriage, female
# 1                         28.7                          26.98
#
#     Age_Dependency_Ratio_Old   Age_Dependency_Ratio_Young  \
# 0  Age dependency ratio, old  Age dependency ratio, young
# 1                18.95421925                  25.54087375
#
#   Completeness_Birth_Registration_Percent  \
# 0  Completeness of birth registration (%)
# 1                                   100.0
#
#              Completeness_Death_Registration_Percent
# 0  Completeness of death registration with cause-...
# 1                                                NaN

# %% [markdown]
# Add Country Name, Year, Continent, Region, Capital, Currency columns

# %%
count = 5
iterator = 0;
countries = ["Canada", "USA", "Mexico", "Burundi", "Chad", "Niger", "Bolivia", "Philippines", "Indonesia"]

# regions from https://www.thoughtco.com/official-listing-of-countries-world-region-1435153
regions = ["North America", "North America", "North America", "Sub-Saharan Africa", "Sub-Saharan Africa", "Sub-Saharan Africa", "South America", "Asia", "Asia"]
continents = ["North America", "North America", "North America", "Africa", "Africa", "Africa", "South America", "Asia", "Asia"]

# currencies from https://www.countries-ofthe-world.com/world-currencies.html
currencies = ["CAD", "USD", "MXN", "BIF", "XAF", "XOF", "BOB", "PHP", "IDR"]

# capital cities from https://www.countries-ofthe-world.com/capitals-of-the-world.html
capitals = ["Ottawa", "Washington, D.C.", "Mexico City", "Gitega", "N'Djamena", "Niamey", "Sucre, La Paz", "Manila", "Jakarta"]

country_gen_df = pd.DataFrame(columns=["Country","Year"])

pop_data = {}
pop_data["Country"] = "Blank"
  
country_gen_df = country_gen_df.append(pd.DataFrame([pop_data]), ignore_index=True)


for i in range(144):
    if count>20:
        count = 5
        iterator = iterator + 1
    pop_data["Country_Key"] = i
    pop_data["Year"] = 2000+count
    pop_data["Continent"] = continents[iterator]
    pop_data["Region"] = regions[iterator]
    pop_data["Country"] = countries[iterator]
    pop_data["Capital"] = capitals[iterator]
    pop_data["Currency"] = currencies[iterator]

    count = count + 1
    country_gen_df = country_gen_df.append(pd.DataFrame([pop_data]), ignore_index=True)

display(country_gen_df.head(5))
# Out:
#   Country  Year  Country_Key      Continent         Region Capital Currency
# 0   Blank   NaN          NaN            NaN            NaN     NaN      NaN
# 1  Canada  2005          0.0  North America  North America  Ottawa      CAD
# 2  Canada  2006          1.0  North America  North America  Ottawa      CAD
# 3  Canada  2007          2.0  North America  North America  Ottawa      CAD
# 4  Canada  2008          3.0  North America  North America  Ottawa      CAD

# %% [markdown]
# Join the two dataframes

# %%
final_table = pd.concat([country_gen_df, final_table], axis=1)
display(final_table.head(2))
# Out:
#   Country  Year  Country_Key      Continent         Region Capital Currency  \
# 0   Blank   NaN          NaN            NaN            NaN     NaN      NaN
# 1  Canada  2005          0.0  North America  North America  Ottawa      CAD
#
#               Birth_Rate_Crude_Per_1000 Population_Total_Count  \
# 0  Birth rate, crude (per 1,000 people)      Population, total
# 1                                  10.6               32243753
#
#               Death_Rate_Crude_Per_1000  \
# 0  Death rate, crude (per 1,000 people)
# 1                                   7.1
#
#                            GNI_Per_Capita_USD  \
# 0  GNI per capita, Atlas method (current US$)
# 1                                       34810
#
#                     Labour_Force_Female_Percent Labour_Force_Total_Count  \
# 0  Labor force, female (% of total labor force)       Labor force, total
# 1                                   46.63737609                 17821886
#
#             Age_Dependency_Ratio_Percent_Working_Age  \
# 0  Age dependency ratio (% of working-age populat...
# 1                                          44.495093
#
#        Age_First_Marriage_Male      Age_First_Marriage_Female  \
# 0  Age at first marriage, male  Age at first marriage, female
# 1                         28.7                          26.98
#
#     Age_Dependency_Ratio_Old   Age_Dependency_Ratio_Young  \
# 0  Age dependency ratio, old  Age dependency ratio, young
# 1                18.95421925                  25.54087375
#
#   Completeness_Birth_Registration_Percent  \
# 0  Completeness of birth registration (%)
# 1                                   100.0
#
#              Completeness_Death_Registration_Percent
# 0  Completeness of death registration with cause-...
# 1                                                NaN

# %% [markdown]
# Remove Columns and Rows that  will not be used

# %%
#Row 0 was a placeholder that can be removed
final_table = final_table.drop(0)

#Death certification had too little data to use
final_table = final_table.drop(["Completeness_Death_Registration_Percent"], axis=1)

final_table['Country_Key'] = final_table['Country_Key'].astype(int)
#Display final table
final_table.head(200)
# Out:
#        Country  Year  Country_Key      Continent         Region  Capital  \
# 1       Canada  2005            0  North America  North America   Ottawa
# 2       Canada  2006            1  North America  North America   Ottawa
# 3       Canada  2007            2  North America  North America   Ottawa
# 4       Canada  2008            3  North America  North America   Ottawa
# 5       Canada  2009            4  North America  North America   Ottawa
# ..         ...   ...          ...            ...            ...      ...
# 140  Indonesia  2016          139           Asia           Asia  Jakarta
# 141  Indonesia  2017          140           Asia           Asia  Jakarta
# 142  Indonesia  2018          141           Asia           Asia  Jakarta
# 143  Indonesia  2019          142           Asia           Asia  Jakarta
# 144  Indonesia  2020          143           Asia           Asia  Jakarta
#
#     Currency Birth_Rate_Crude_Per_1000 Population_Total_Count  \
# 1        CAD                      10.6               32243753
# 2        CAD                      10.9               32571174
# 3        CAD                      11.2               32889025
# 4        CAD                      11.3               33247118
# 5        CAD                      11.3               33628895
# ..       ...                       ...                    ...
# 140      IDR                    18.245              123333379
# 141      IDR                    17.918              124777326
# 142      IDR                    17.602              126190782
# 143      IDR                    17.297              127575529
# 144      IDR                    17.297              128932753
#
#     Death_Rate_Crude_Per_1000 GNI_Per_Capita_USD Labour_Force_Female_Percent  \
# 1                         7.1              34810                 46.63737609
# 2                           7              38510                  46.8751721
# 3                         7.1              43090                  47.0367127
# 4                         7.2              45650                 46.97475419
# 5                         7.1              43230                 47.20037683
# ..                        ...                ...                         ...
# 140                     5.851               9390                 37.60167967
# 141                     5.933               8920                  37.3923288
# 142                      6.01               9180                 37.71694562
# 143                     6.082               9470                 38.43918557
# 144                     6.082               8480                 38.11371726
#
#     Labour_Force_Total_Count Age_Dependency_Ratio_Percent_Working_Age  \
# 1                   17821886                                44.495093
# 2                   18030705                              44.23699432
# 3                   18379605                              44.03477573
# 4                   18667574                              43.93390259
# 5                   18799155                              43.97675318
# ..                       ...                                      ...
# 140                 53507498                               51.9253744
# 141                 54096291                              51.46924186
# 142                 55190039                              51.01299485
# 143                 56596004                              50.60644416
# 144                 53080123                              50.27056808
#
#     Age_First_Marriage_Male Age_First_Marriage_Female  \
# 1                      28.7                     26.98
# 2                      28.6                      26.6
# 3                      28.7                     26.98
# 4                      28.7                     26.98
# 5                      28.7                     26.98
# ..                      ...                       ...
# 140                    25.9                      23.2
# 141               25.885714                 23.285714
# 142                    25.9                      23.2
# 143                    25.9                      23.2
# 144               25.885714                 23.285714
#
#     Age_Dependency_Ratio_Old Age_Dependency_Ratio_Young  \
# 1                18.95421925                25.54087375
# 2                19.13834588                25.09864844
# 3                19.35344295                24.68133278
# 4                19.62097814                24.31292445
# 5                19.96659698                 24.0101562
# ..                       ...                        ...
# 140              10.44231738                41.48305702
# 141               10.6646015                40.80464036
# 142              10.90870355                 40.1042913
# 143              11.16996881                39.43647534
# 144              11.44776791                38.82280017
#
#     Completeness_Birth_Registration_Percent
# 1                                     100.0
# 2                                     100.0
# 3                                     100.0
# 4                                     100.0
# 5                                     100.0
# ..                                      ...
# 140                                    94.2
# 141                                    94.2
# 142                                    94.2
# 143                                    94.2
# 144                                    94.2
#
# [144 rows x 19 columns]

# %% [markdown]
# Generate CSV File

# %%
final_table.to_csv("Country_Processed_Table.csv", index = False, header = True)
