# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import warnings

from datetime import datetime, timedelta
from IPython.display import display

warnings.filterwarnings("ignore")

# %% [markdown]
# Read Event Data

# %%
natural_disaster_data_processed = pd.read_csv("Events_Data_Raw.csv")#read input data
natural_disaster_data_processed.columns = natural_disaster_data_processed.iloc[5]#set the column names
natural_disaster_data_processed = pd.DataFrame(natural_disaster_data_processed, columns=["Year", "Disaster Subgroup", "Disaster Type", "Disaster Subtype", "Country", "Start Month", "End Month", "Start Year", "End Year", "Total Deaths", "No Injured", "No Homeless", "Total Affected"])#filter out only columns we want

countries = ["Canada", "USA", "Mexico", "Burundi", "Chad", "Niger", "Bolivia", "Philippines", "Indonesia"]

natural_disaster_data_processed = natural_disaster_data_processed.drop(natural_disaster_data_processed.index[0:6], axis=0)
natural_disaster_data_processed = natural_disaster_data_processed.sort_values(by=['Country','Year'], ascending=[True,True])

##replace country names with preset names
natural_disaster_data_processed["Country"].replace({"Philippines (the)": "Philippines"}, inplace=True)
natural_disaster_data_processed["Country"].replace({"United States of America (the)": "USA"}, inplace=True)
natural_disaster_data_processed["Country"].replace({"Niger (the)": "Niger"}, inplace=True)
natural_disaster_data_processed["Country"].replace({"Bolivia (Plurinational State of)": "Bolivia"}, inplace=True)

##set NaN values to 0
natural_disaster_data_processed["Total Deaths"].replace({np.NaN: 0}, inplace=True)
natural_disaster_data_processed["No Injured"].replace({np.NaN: 0}, inplace=True)
natural_disaster_data_processed["No Homeless"].replace({np.NaN: 0}, inplace=True)
natural_disaster_data_processed["Total Affected"].replace({np.NaN: 0}, inplace=True)

natural_disaster_data_processed['Total Affected'] = natural_disaster_data_processed['Total Affected'].astype(int)

finalframe = natural_disaster_data_processed.iloc[0:0, :]

for country in countries:
    countryframe = natural_disaster_data_processed.loc[natural_disaster_data_processed['Country'] == country]
    countryframe = countryframe.dropna()
    # countryframe["Total Affected"] = countryframe["Total Affected"].nlargest(n=10)
    countryframe = countryframe.nlargest(10, "Total Affected", keep='first')
    finalframe = finalframe.append(countryframe, ignore_index=True)

finalframe.columns = ["Year_Ref", "Disaster_Subgroup", "Disaster_Type", "Disaster_Subtype", "Country_Name", "Start_Month", "End_Month", "Start_Year", "End_Year", "Total_Deaths", "Total_Injuries", "Total_Homeless", "Total_Affected"]
finalframe["Event_Key"] = np.arange(len(finalframe))
finalframe = pd.DataFrame(finalframe, columns=["Event_Key", "Year_Ref", "Disaster_Subgroup", "Disaster_Type", "Disaster_Subtype", "Country_Name", "Start_Month", "End_Month", "Start_Year", "End_Year", "Total_Deaths", "Total_Injuries", "Total_Homeless", "Total_Affected"])#filter out only columns we want
finalframe.head(50)
# Out:
#     Event_Key Year_Ref  Disaster_Subgroup        Disaster_Type  \
# 0           0     2013       Hydrological                Flood
# 1           1     2016     Climatological             Wildfire
# 2           2     2020     Meteorological                Storm
# 3           3     2015     Climatological             Wildfire
# 4           4     2020       Hydrological                Flood
# 5           5     2008      Technological  Industrial accident
# 6           6     2011     Climatological             Wildfire
# 7           7     2014       Hydrological                Flood
# 8           8     2005       Hydrological                Flood
# 9           9     2018     Climatological             Wildfire
# 10         10     2016     Meteorological                Storm
# 11         11     2008       Hydrological                Flood
# 12         12     2008     Meteorological                Storm
# 13         13     2018     Meteorological                Storm
# 14         14     2007     Climatological             Wildfire
# 15         15     2017     Meteorological                Storm
# 16         16     2005     Meteorological                Storm
# 17         17     2011     Meteorological                Storm
# 18         18     2005     Meteorological                Storm
# 19         19     2018     Climatological             Wildfire
# 20         20     2011     Climatological              Drought
# 21         21     2005     Meteorological                Storm
# 22         22     2007       Hydrological                Flood
# 23         23     2017        Geophysical           Earthquake
# 24         24     2005     Meteorological                Storm
# 25         25     2010       Hydrological                Flood
# 26         26     2008     Meteorological                Storm
# 27         27     2011     Meteorological                Storm
# 28         28     2017        Geophysical           Earthquake
# 29         29     2011       Hydrological                Flood
# 30         30     2005     Climatological              Drought
# 31         31     2007  Complex Disasters    Complex Disasters
# 32         32     2009     Climatological              Drought
# 33         33     2008     Climatological              Drought
# 34         34     2007       Hydrological                Flood
# 35         35     2014       Hydrological                Flood
# 36         36     2018       Hydrological                Flood
# 37         37     2019       Hydrological            Landslide
# 38         38     2009       Hydrological                Flood
# 39         39     2005       Hydrological                Flood
# 40         40     2009     Climatological              Drought
# 41         41     2017     Climatological              Drought
# 42         42     2012     Climatological              Drought
# 43         43     2012       Hydrological                Flood
# 44         44     2007       Hydrological                Flood
# 45         45     2010       Hydrological                Flood
# 46         46     2012       Hydrological                Flood
# 47         47     2011         Biological             Epidemic
# 48         48     2009       Hydrological                Flood
# 49         49     2008       Hydrological                Flood
#
#                     Disaster_Subtype Country_Name Start_Month End_Month  \
# 0                     Riverine flood       Canada           6         6
# 1                        Forest fire       Canada           5         7
# 2                   Convective storm       Canada           6         6
# 3                        Forest fire       Canada           7         7
# 4                     Riverine flood       Canada           4         4
# 5                          Explosion       Canada           8         8
# 6                        Forest fire       Canada           5         5
# 7                        Flash flood       Canada           8         8
# 8                     Riverine flood       Canada           6         7
# 9                        Forest fire       Canada           7         8
# 10                  Convective storm          USA           1         1
# 11                    Riverine flood          USA           6         6
# 12                  Tropical cyclone          USA           9         9
# 13                  Tropical cyclone          USA           9         9
# 14  Land fire (Brush, Bush, Pasture)          USA          10        10
# 15                  Tropical cyclone          USA           8         8
# 16                  Tropical cyclone          USA           8         9
# 17                  Tropical cyclone          USA           8         9
# 18                  Tropical cyclone          USA           9        10
# 19                       Forest fire          USA           6        12
# 20                           Drought       Mexico           9        12
# 21                  Tropical cyclone       Mexico          10        10
# 22                    Riverine flood       Mexico          10        11
# 23                   Ground movement       Mexico           9         9
# 24                  Tropical cyclone       Mexico          10        10
# 25                    Riverine flood       Mexico           9         9
# 26                  Tropical cyclone       Mexico           7         7
# 27                  Tropical cyclone       Mexico           6         7
# 28                   Ground movement       Mexico           9         9
# 29                    Riverine flood       Mexico          10        10
# 30                           Drought      Burundi           1         1
# 31                            Famine      Burundi           2         2
# 32                           Drought      Burundi          12         2
# 33                           Drought      Burundi           9         1
# 34                    Riverine flood      Burundi           1         1
# 35                       Flash flood      Burundi           2         3
# 36                       Flash flood      Burundi           1         1
# 37                         Landslide      Burundi          12        12
# 38                    Riverine flood      Burundi           4         4
# 39                       Flash flood      Burundi           2         2
# 40                           Drought         Chad          12         7
# 41                           Drought         Chad           3         5
# 42                           Drought         Chad           6         2
# 43                    Riverine flood         Chad           7         9
# 44                    Riverine flood         Chad           8         9
# 45                    Riverine flood         Chad           8         9
# 46                    Riverine flood         Chad           9        10
# 47                 Bacterial disease         Chad           8        10
# 48                    Riverine flood         Chad           8         8
# 49                    Riverine flood         Chad           9         9
#
#    Start_Year End_Year Total_Deaths Total_Injuries Total_Homeless  \
# 0        2013     2013            4              0              0
# 1        2016     2016            0              0              0
# 2        2020     2020            0              0              0
# 3        2015     2015            0              0             36
# 4        2020     2020            1              0              0
# 5        2008     2008            2             18              0
# 6        2011     2011            1              0           7000
# 7        2014     2014            0              4              0
# 8        2005     2005            4              0              0
# 9        2018     2018            0              0              0
# 10       2016     2016           50             12              0
# 11       2008     2008           24            148              0
# 12       2008     2008           43              0              0
# 13       2018     2018           53              0              0
# 14       2007     2007            8             64              0
# 15       2017     2017           88             24          27000
# 16       2005     2005         1833              0              0
# 17       2011     2011           46              0              0
# 18       2005     2005           10              0              0
# 19       2018     2018           88              0              0
# 20       2011     2011            0              0              0
# 21       2005     2005           36              0              0
# 22       2007     2007           22              0              0
# 23       2017     2017           98            250              0
# 24       2005     2005            7              0         300000
# 25       2010     2010           25              0              0
# 26       2008     2008            2              0              0
# 27       2011     2011           22              0              0
# 28       2017     2017          369           6000              0
# 29       2011     2011            0              0              0
# 30       2005     2006          120              0              0
# 31       2007     2007            0              0              0
# 32       2009     2010            0              0              0
# 33       2008     2009            0              0              0
# 34       2007     2007            4              0          23000
# 35       2014     2014           96            182          12500
# 36       2018     2018            0              0              0
# 37       2019     2019           37              7              0
# 38       2009     2009            0              0              0
# 39       2005     2005            0              0           5000
# 40       2009     2010            0              0              0
# 41       2017     2017            0              0              0
# 42       2012     2013            0              0              0
# 43       2012     2012           20              0              0
# 44       2007     2007           12              0              0
# 45       2010     2010           24              0              0
# 46       2012     2012            0              0              0
# 47       2011     2011          433              0              0
# 48       2009     2009            3              0            900
# 49       2008     2008            0              0              0
#
#     Total_Affected
# 0           100000
# 1            88000
# 2            60000
# 3            13036
# 4            12936
# 5            12518
# 6             7000
# 7             6904
# 8             5000
# 9             3000
# 10        85000012
# 11        11000148
# 12         2100000
# 13         1500000
# 14          640064
# 15          582024
# 16          500000
# 17          370000
# 18          300000
# 19          250000
# 20         2500000
# 21         1954571
# 22         1600000
# 23         1200250
# 24         1000000
# 25         1000000
# 26          500000
# 27          300000
# 28          256000
# 29          250000
# 30         2150000
# 31         2000000
# 32          180000
# 33           82500
# 34           23000
# 35           12682
# 36           12000
# 37            9942
# 38            8000
# 39            5000
# 40         2400000
# 41         1886800
# 42         1600000
# 43          594831
# 44          170000
# 45          144579
# 46           18800
# 47           16038
# 48            8020
# 49            8000

# %% [markdown]
# Export to CSV for Fact Table

# %%
finalframe.to_csv("Event_Pro_Table.csv", index = False, header = True)

# %% [markdown]
# Export to CSV for DB

# %%
final_table = finalframe.drop(columns=["Country_Name", "Year_Ref"])
display(final_table.head())
final_table.to_csv("Event_Pro_DB.csv", index = False, header = True)
# Out:
#    Event_Key Disaster_Subgroup Disaster_Type  Disaster_Subtype Start_Month  \
# 0          0      Hydrological         Flood    Riverine flood           6
# 1          1    Climatological      Wildfire       Forest fire           5
# 2          2    Meteorological         Storm  Convective storm           6
# 3          3    Climatological      Wildfire       Forest fire           7
# 4          4      Hydrological         Flood    Riverine flood           4
#
#   End_Month Start_Year End_Year Total_Deaths Total_Injuries Total_Homeless  \
# 0         6       2013     2013            4              0              0
# 1         7       2016     2016            0              0              0
# 2         6       2020     2020            0              0              0
# 3         7       2015     2015            0              0             36
# 4         4       2020     2020            1              0              0
#
#    Total_Affected
# 0          100000
# 1           88000
# 2           60000
# 3           13036
# 4           12936
