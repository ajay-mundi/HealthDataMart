# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import warnings

from datetime import datetime, timedelta
from IPython.display import display

warnings.filterwarnings("ignore")

# %% [markdown]
# Read Data with Pandas

# %%
pop_data_raw = pd.read_csv("Pop_Data_Raw.csv")#read input data

pop_transposed = pop_data_raw.transpose()#flip dataframe

final_table = pop_transposed.iloc[2:3,0:12]#create data frame header columns

count_start = 0
count_end = 12
for i in range(9):
    transposed_country = pop_transposed.iloc[4:, count_start: count_end]
    transposed_country.columns = range(transposed_country.columns.size)
    final_table = pd.concat([final_table, transposed_country], axis=0, ignore_index=True)
    count_start = count_end 
    count_end = count_end + 12

final_table.head(1)
# Out:
#                                               0   \
# 0  Population ages 15-64 (% of total population)
#
#                                                   1   \
# 0  Population ages 65 and above (% of total popul...
#
#                              2                                           3   \
# 0  Population growth (annual %)  Population, female (% of total population)
#
#                                          4   \
# 0  Population, male (% of total population)
#
#                                          5   \
# 0  Rural population (% of total population)
#
#                                    6   \
# 0  Rural population growth (annual %)
#
#                                          7   \
# 0  Urban population (% of total population)
#
#                                    8   \
# 0  Urban population growth (annual %)
#
#                                         9   \
# 0  Life expectancy at birth, total (years)
#
#                                        10  \
# 0  Life expectancy at birth, male (years)
#
#                                          11
# 0  Life expectancy at birth, female (years)

# %% [markdown]
# Create Population Dataframe

# %%
final_table.columns=["Population_15To64_Percent", "Population_65andUp_Percent","Population_Growth_Percent", "Population_Female_Percent", "Population_Male_Percent", "Rural_Population_Percent", "Rural_Population_Growth_Percent", "Urban_Population_Percent", "Urban_Population_Growth_Percent", "Life_Exp_Birth_Total_Yr", "Life_Exp_Birth_Male_Yr", "Life_Exp_Birth_Female_Yr"]

# %% [markdown]
# Add Country Name and Year

# %%
count = 5
iterator = 0;
countries = ["Canada", "USA", "Mexico", "Burundi", "Chad", "Niger", "Bolivia", "Philippines", "Indonesia"]

country_year = pd.DataFrame(columns=["Country","Year"])

pop_data = {}
pop_data["Country"] = "Blank"
pop_data["Year"] = 0
  
country_year = country_year.append(pd.DataFrame([pop_data]), ignore_index=True)


for i in range(144):
    if count>20:
        count = 5
        iterator = iterator + 1

    pop_data["Population_Key"] = i
    pop_data["Year"] = 2000+count
    pop_data["Country"] = countries[iterator]
    count = count + 1
    country_year = country_year.append(pd.DataFrame([pop_data]), ignore_index=True)

display(country_year.tail(5))
# Out:
#        Country  Year  Population_Key
# 140  Indonesia  2016           139.0
# 141  Indonesia  2017           140.0
# 142  Indonesia  2018           141.0
# 143  Indonesia  2019           142.0
# 144  Indonesia  2020           143.0

# %% [markdown]
# Join Country_Year with Final_Table

# %%
final_table = pd.concat([country_year, final_table], axis=1)
display(final_table.tail(20))
# Out:
#          Country  Year  Population_Key Population_15To64_Percent  \
# 125  Philippines  2017           124.0                 63.594895
# 126  Philippines  2018           125.0                 63.914391
# 127  Philippines  2019           126.0                 64.209123
# 128  Philippines  2020           127.0          64.4456728195355
# 129    Indonesia  2005           128.0                  65.31797
# 130    Indonesia  2006           129.0                 65.610642
# 131    Indonesia  2007           130.0                 65.836215
# 132    Indonesia  2008           131.0                 66.003012
# 133    Indonesia  2009           132.0                 66.119766
# 134    Indonesia  2010           133.0                 66.209384
# 135    Indonesia  2011           134.0                 66.431675
# 136    Indonesia  2012           135.0                 66.607676
# 137    Indonesia  2013           136.0                 66.770053
# 138    Indonesia  2014           137.0                 66.953568
# 139    Indonesia  2015           138.0                 67.165592
# 140    Indonesia  2016           139.0                  67.24298
# 141    Indonesia  2017           140.0                  67.40315
# 142    Indonesia  2018           141.0                 67.591637
# 143    Indonesia  2019           142.0                 67.734578
# 144    Indonesia  2020           143.0          67.8014803219093
#
#     Population_65andUp_Percent Population_Growth_Percent  \
# 125                   4.937097                  1.445278
# 126                   5.122569                  1.395965
# 127                   5.314996                  1.364496
# 128           5.51164864430335          1.34542996462104
# 129                   4.800765                  1.336305
# 130                   4.868223                  1.329582
# 131                   4.918852                  1.323834
# 132                   4.952434                  1.323331
# 133                   4.967382                  1.329217
# 134                   4.962514                  1.337782
# 135                   5.044132                  1.347904
# 136                   5.117567                    1.3517
# 137                   5.192082                  1.340771
# 138                   5.278582                  1.310945
# 139                   5.383435                   1.26783
# 140                   5.524336                  1.220591
# 141                   5.681948                  1.176197
# 142                   5.857166                  1.134507
# 143                   6.050303                  1.097926
# 144           6.26251338481323          1.06517898587775
#
#     Population_Female_Percent Population_Male_Percent  \
# 125                 49.721566               50.278434
# 126                 49.741657               50.258343
# 127                  49.76159                50.23841
# 128          49.7825514321199        50.2174485678801
# 129                 49.802177               50.197823
# 130                 49.762018               50.237982
# 131                 49.720245               50.279755
# 132                 49.680785               50.319215
# 133                 49.648484               50.351516
# 134                 49.626442               50.373558
# 135                 49.615988               50.384012
# 136                 49.615539               50.384461
# 137                 49.621626               50.378374
# 138                  49.62947                50.37053
# 139                  49.63573                50.36427
# 140                 49.639592               50.360408
# 141                 49.642056               50.357944
# 142                 49.643882               50.356118
# 143                 49.646383               50.353617
# 144          49.6504687615261        50.3495312384739
#
#     Rural_Population_Percent Rural_Population_Growth_Percent  \
# 125                   53.318                        1.057793
# 126                   53.093                        0.973077
# 127                   52.851                         0.90765
# 128                   52.592               0.854167721331776
# 129                   54.058                       -0.119983
# 130                   53.262                        -0.15386
# 131                   52.465                       -0.183852
# 132                   51.665                        -0.21324
# 133                   50.866                       -0.229367
# 134                   50.086                       -0.207537
# 135                   49.405                       -0.021085
# 136                   48.724                       -0.036292
# 137                   48.045                       -0.062594
# 138                   47.365                       -0.114506
# 139                   46.687                       -0.173951
# 140                   46.011                       -0.237934
# 141                   45.341                       -0.290682
# 142                   44.675                       -0.345257
# 143                   44.015                       -0.390432
# 144                   43.359              -0.436439683580507
#
#     Urban_Population_Percent Urban_Population_Growth_Percent  \
# 125                   46.682                        1.889689
# 126                   46.907                        1.876791
# 127                   47.149                        1.879085
# 128                   47.408                1.89324969217441
# 129                   45.942                        3.077465
# 130                   46.738                        3.047363
# 131                   47.535                        3.014709
# 132                   48.335                        2.992295
# 133                   49.134                         2.96875
# 134                   49.914                        2.912809
# 135                   50.595                        2.703027
# 136                   51.276                        2.688705
# 137                   51.955                        2.656286
# 138                   52.635                        2.611279
# 139                   53.313                         2.54772
# 140                   53.989                        2.480603
# 141                   54.659                        2.409554
# 142                   55.325                        2.345607
# 143                   55.985                        2.283818
# 144                   56.641                2.23010935628228
#
#     Life_Exp_Birth_Total_Yr Life_Exp_Birth_Male_Yr Life_Exp_Birth_Female_Yr
# 125                  70.952                 66.971                   75.268
# 126                  71.095                 67.123                   75.387
# 127                  71.231                 67.263                   75.505
# 128                      ..                     ..                       ..
# 129                  67.334                 65.579                   69.107
# 130                  67.717                 65.899                   69.565
# 131                  68.105                 66.228                   70.025
# 132                  68.485                 66.554                   70.474
# 133                  68.853                 66.872                   70.905
# 134                  69.205                 67.182                   71.311
# 135                  69.542                 67.485                    71.69
# 136                  69.866                 67.784                   72.047
# 137                  70.179                 68.081                   72.383
# 138                  70.481                 68.371                   72.698
# 139                  70.768                 68.651                   72.992
# 140                  71.035                 68.914                   73.264
# 141                  71.282                 69.156                   73.515
# 142                  71.509                 69.375                   73.748
# 143                  71.716                 69.572                   73.967
# 144                      ..                     ..                       ..

# %% [markdown]
# Fill in Empty Cells

# %%
#Replace emply values with NaN
final_table['Life_Exp_Birth_Female_Yr'].replace({'..': np.NaN}, inplace = True)
final_table['Life_Exp_Birth_Male_Yr'].replace({'..': np.NaN}, inplace = True)
final_table['Life_Exp_Birth_Total_Yr'].replace({'..': np.NaN}, inplace = True)

#Replace NaN values with last observation
final_table.fillna(method="ffill", inplace=True)


display(final_table.head(20))
# Out:
#    Country  Year  Population_Key  \
# 0    Blank     0             NaN
# 1   Canada  2005             0.0
# 2   Canada  2006             1.0
# 3   Canada  2007             2.0
# 4   Canada  2008             3.0
# 5   Canada  2009             4.0
# 6   Canada  2010             5.0
# 7   Canada  2011             6.0
# 8   Canada  2012             7.0
# 9   Canada  2013             8.0
# 10  Canada  2014             9.0
# 11  Canada  2015            10.0
# 12  Canada  2016            11.0
# 13  Canada  2017            12.0
# 14  Canada  2018            13.0
# 15  Canada  2019            14.0
# 16  Canada  2020            15.0
# 17     USA  2005            16.0
# 18     USA  2006            17.0
# 19     USA  2007            18.0
#
#                         Population_15To64_Percent  \
# 0   Population ages 15-64 (% of total population)
# 1                                       69.206502
# 2                                       69.330341
# 3                                       69.427679
# 4                                       69.476335
# 5                                       69.455658
# 6                                       69.357773
# 7                                       69.133519
# 8                                        68.89938
# 9                                       68.630895
# 10                                       68.31509
# 11                                      67.954884
# 12                                      67.646956
# 13                                      67.287472
# 14                                      66.897742
# 15                                      66.506203
# 16                               66.1203862397467
# 17                                      66.807154
# 18                                      66.801557
# 19                                      66.838224
#
#                            Population_65andUp_Percent  \
# 0   Population ages 65 and above (% of total popul...
# 1                                           13.117552
# 2                                           13.268681
# 3                                           13.436645
# 4                                           13.631938
# 5                                           13.867931
# 6                                           14.153651
# 7                                           14.451218
# 8                                           14.803899
# 9                                           15.201846
# 10                                          15.623366
# 11                                          16.053635
# 12                                           16.45501
# 13                                          16.842492
# 14                                          17.232007
# 15                                          17.647897
# 16                                   18.1043615051754
# 17                                          12.311711
# 18                                          12.380916
# 19                                          12.471868
#
#        Population_Growth_Percent                   Population_Female_Percent  \
# 0   Population growth (annual %)  Population, female (% of total population)
# 1                       0.944467                                   50.425044
# 2                       1.010335                                   50.415091
# 3                       0.971135                                   50.404456
# 4                       1.082907                                   50.394821
# 5                       1.141758                                   50.388411
# 6                       1.111864                                   50.386484
# 7                       0.978698                                   50.389737
# 8                       1.085817                                   50.397092
# 9                       1.056591                                   50.405809
# 10                      1.005338                                   50.412305
# 11                      0.746339                                   50.414127
# 12                      1.132349                                   50.410566
# 13                      1.199682                                   50.402562
# 14                      1.412548                                    50.39153
# 15                      1.415015                                   50.379516
# 16              1.08959148655862                            50.3680248057894
# 17                      0.921713                                   50.653802
# 18                      0.964254                                   50.643896
# 19                      0.951055                                   50.636785
#
#                      Population_Male_Percent  \
# 0   Population, male (% of total population)
# 1                                  49.574956
# 2                                  49.584909
# 3                                  49.595544
# 4                                  49.605179
# 5                                  49.611589
# 6                                  49.613516
# 7                                  49.610263
# 8                                  49.602908
# 9                                  49.594191
# 10                                 49.587695
# 11                                 49.585873
# 12                                 49.589434
# 13                                 49.597438
# 14                                  49.60847
# 15                                 49.620484
# 16                          49.6319751942105
# 17                                 49.346198
# 18                                 49.356104
# 19                                 49.363215
#
#                     Rural_Population_Percent  \
# 0   Rural population (% of total population)
# 1                                     19.878
# 2                                     19.787
# 3                                     19.604
# 4                                     19.422
# 5                                     19.242
# 6                                     19.063
# 7                                     18.904
# 8                                     18.863
# 9                                     18.822
# 10                                    18.782
# 11                                    18.741
# 12                                      18.7
# 13                                     18.65
# 14                                    18.589
# 15                                    18.518
# 16                                    18.438
# 17                                    20.072
# 18                                    19.901
# 19                                    19.731
#
#        Rural_Population_Growth_Percent  \
# 0   Rural population growth (annual %)
# 1                             0.557844
# 2                             0.551491
# 3                             0.041978
# 4                             0.150192
# 5                             0.210657
# 6                             0.177253
# 7                              0.14113
# 8                             0.868694
# 9                             0.838999
# 10                            0.792588
# 11                            0.527808
# 12                            0.913336
# 13                            0.931952
# 14                            1.084928
# 15                            1.032338
# 16                   0.656644458992974
# 17                             0.07339
# 18                             0.10867
# 19                            0.093157
#
#                     Urban_Population_Percent  \
# 0   Urban population (% of total population)
# 1                                     80.122
# 2                                     80.213
# 3                                     80.396
# 4                                     80.578
# 5                                     80.758
# 6                                     80.937
# 7                                     81.096
# 8                                     81.137
# 9                                     81.178
# 10                                    81.218
# 11                                    81.259
# 12                                      81.3
# 13                                     81.35
# 14                                    81.411
# 15                                    81.482
# 16                                    81.562
# 17                                    79.928
# 18                                    80.099
# 19                                    80.269
#
#        Urban_Population_Growth_Percent  \
# 0   Urban population growth (annual %)
# 1                             1.040619
# 2                             1.123847
# 3                             1.199019
# 4                              1.30903
# 5                             1.364894
# 6                             1.333269
# 7                             1.174953
# 8                             1.136362
# 9                              1.10711
# 10                            1.054601
# 11                            0.796808
# 12                            1.182792
# 13                            1.261162
# 14                            1.487506
# 15                            1.502188
# 16                    1.18772430444538
# 17                            1.135885
# 18                            1.177968
# 19                            1.163068
#
#                     Life_Exp_Birth_Total_Yr  \
# 0   Life expectancy at birth, total (years)
# 1                                 80.192683
# 2                                 80.343902
# 3                                 80.543902
# 4                                 80.695122
# 5                                 80.995122
# 6                                 81.246341
# 7                                  81.44878
# 8                                  81.64878
# 9                                  81.74878
# 10                                     81.8
# 11                                     81.9
# 12                                     81.9
# 13                                     81.9
# 14                                 82.04878
# 15                                 82.04878
# 16                                 82.04878
# 17                                77.487805
# 18                                77.687805
# 19                                77.987805
#
#                     Life_Exp_Birth_Male_Yr  \
# 0   Life expectancy at birth, male (years)
# 1                                     77.9
# 2                                     78.1
# 3                                     78.3
# 4                                     78.5
# 5                                     78.8
# 6                                     79.1
# 7                                     79.4
# 8                                     79.6
# 9                                     79.7
# 10                                    79.8
# 11                                    79.9
# 12                                    79.9
# 13                                    79.9
# 14                                    80.0
# 15                                    80.0
# 16                                    80.0
# 17                                    75.0
# 18                                    75.2
# 19                                    75.5
#
#                     Life_Exp_Birth_Female_Yr
# 0   Life expectancy at birth, female (years)
# 1                                       82.6
# 2                                       82.7
# 3                                       82.9
# 4                                       83.0
# 5                                       83.3
# 6                                       83.5
# 7                                       83.6
# 8                                       83.8
# 9                                       83.9
# 10                                      83.9
# 11                                      84.0
# 12                                      84.0
# 13                                      84.0
# 14                                      84.2
# 15                                      84.2
# 16                                      84.2
# 17                                      80.1
# 18                                      80.3
# 19                                      80.6

# %% [markdown]
# Remove Original Labels

# %%
pop_data = final_table.drop(0)
pop_data.head(200)
# Out:
#        Country  Year  Population_Key Population_15To64_Percent  \
# 1       Canada  2005             0.0                 69.206502
# 2       Canada  2006             1.0                 69.330341
# 3       Canada  2007             2.0                 69.427679
# 4       Canada  2008             3.0                 69.476335
# 5       Canada  2009             4.0                 69.455658
# ..         ...   ...             ...                       ...
# 140  Indonesia  2016           139.0                  67.24298
# 141  Indonesia  2017           140.0                  67.40315
# 142  Indonesia  2018           141.0                 67.591637
# 143  Indonesia  2019           142.0                 67.734578
# 144  Indonesia  2020           143.0          67.8014803219093
#
#     Population_65andUp_Percent Population_Growth_Percent  \
# 1                    13.117552                  0.944467
# 2                    13.268681                  1.010335
# 3                    13.436645                  0.971135
# 4                    13.631938                  1.082907
# 5                    13.867931                  1.141758
# ..                         ...                       ...
# 140                   5.524336                  1.220591
# 141                   5.681948                  1.176197
# 142                   5.857166                  1.134507
# 143                   6.050303                  1.097926
# 144           6.26251338481323          1.06517898587775
#
#     Population_Female_Percent Population_Male_Percent  \
# 1                   50.425044               49.574956
# 2                   50.415091               49.584909
# 3                   50.404456               49.595544
# 4                   50.394821               49.605179
# 5                   50.388411               49.611589
# ..                        ...                     ...
# 140                 49.639592               50.360408
# 141                 49.642056               50.357944
# 142                 49.643882               50.356118
# 143                 49.646383               50.353617
# 144          49.6504687615261        50.3495312384739
#
#     Rural_Population_Percent Rural_Population_Growth_Percent  \
# 1                     19.878                        0.557844
# 2                     19.787                        0.551491
# 3                     19.604                        0.041978
# 4                     19.422                        0.150192
# 5                     19.242                        0.210657
# ..                       ...                             ...
# 140                   46.011                       -0.237934
# 141                   45.341                       -0.290682
# 142                   44.675                       -0.345257
# 143                   44.015                       -0.390432
# 144                   43.359              -0.436439683580507
#
#     Urban_Population_Percent Urban_Population_Growth_Percent  \
# 1                     80.122                        1.040619
# 2                     80.213                        1.123847
# 3                     80.396                        1.199019
# 4                     80.578                         1.30903
# 5                     80.758                        1.364894
# ..                       ...                             ...
# 140                   53.989                        2.480603
# 141                   54.659                        2.409554
# 142                   55.325                        2.345607
# 143                   55.985                        2.283818
# 144                   56.641                2.23010935628228
#
#     Life_Exp_Birth_Total_Yr Life_Exp_Birth_Male_Yr Life_Exp_Birth_Female_Yr
# 1                 80.192683                   77.9                     82.6
# 2                 80.343902                   78.1                     82.7
# 3                 80.543902                   78.3                     82.9
# 4                 80.695122                   78.5                     83.0
# 5                 80.995122                   78.8                     83.3
# ..                      ...                    ...                      ...
# 140                  71.035                 68.914                   73.264
# 141                  71.282                 69.156                   73.515
# 142                  71.509                 69.375                   73.748
# 143                  71.716                 69.572                   73.967
# 144                  71.716                 69.572                   73.967
#
# [144 rows x 15 columns]

# %% [markdown]
# Generate CSV

# %%
pop_data['Population_Key'] = pop_data['Population_Key'].astype(int)
pop_data.to_csv("Pop_Processed_Table.csv", index = False, header = True)
